# %%
import os
from sklearn import preprocessing
import sys
import numpy as np
import pandas as pd
import pickle
#from azureml.dataprep import package


sys.path.append(".")
sys.path.append("..")



from nltk import wordpunct_tokenize
from nltk.corpus import stopwords



def removeString(data, regex):
    return data.str.lower().str.replace(regex.lower(), ' ')


def cleanDataset(dataset, columnsToClean, regexList):
    for column in columnsToClean:
        for regex in regexList:
            dataset[column] = removeString(dataset[column], regex)
    return dataset

stopwords_fileids_custom=['english','french']

def _calc_ratios(text):
    ratios = {}
    tokens = wordpunct_tokenize(text)
    words = [word.lower() for word in tokens]
#    for lang in stopwords.fileids():
    for lang in stopwords_fileids_custom:
        stopwords_set = set(stopwords.words(lang))
        words_set = set(words)
        common_words = words_set.intersection(stopwords_set)
        ratios[lang] = len(common_words)
    
    is_english=ratios['english']>ratios['french']

    return is_english

# %%
def getRegexList():
    regexList = []
    regexList += ['From:']  # from line
    # regexList += ['RITM[0-9]*'] # request id
    # regexList += ['INC[0-9]*'] # incident id
    # regexList += ['TKT[0-9]*'] # ticket id
    regexList += ['Sent:']  # sent to line
    regexList += ['Received:']  # received data line
    regexList += ['To:','À:']  # to line
    regexList += ['CC:','Cc:']  # cc line
    #regexList += ['The information(.*)infection']  # footer
    #regexList += ['Endava Limited is a company(.*)or omissions']  # footer
    #regexList += ['The information in this email is confidential and may be legally(.*)interference if you are not the intended recipient']  # footer
    regexList += ['\[cid:(.*)]']  # images cid
    regexList += ['https?:[^\]\n\r]+']  # https & http
    regexList += ['Subject:','Objet:','Object:']
    # regexList += ['[\w\d\-\_\.]+@[\w\d\-\_\.]+']  # emails
    # regexList += ['[0-9][\-0–90-9 ]+']  # phones
    # regexList += ['[0-9]']  # numbers
    # regexList += ['[^a-zA-z 0-9]+']  # anything that is not a letter
    # regexList += ['[\r\n]']  # \r\n
    regexList += [' [a-zA-Z] ']  # single letters
    # regexList += [' [a-zA-Z][a-zA-Z] ']  # two-letter words
    regexList += ["  "]  # double spaces

    regexList += ['^[_a-z0-9-]+(\.[_a-z0-9-]+)*@[a-z0-9-]+(\.[a-z0-9-]+)*(\.[a-z]{2,4})$']
    regexList += ['[\w\d\-\_\.]+ @ [\w\d\-\_\.]+']
    #regexList += ['[^a-zA-Z]']
    # Customized Part
    cust_stopwords=[]
    cust_stopwords+=['Note: Please check the attachments tab for complete email including print screens or attachments']
    cust_stopwords+=['Importance','urgent','Tel','Fax']
    cust_stopwords+=['Descriptif de','incident :','Depuis quand :','Information requises :']
    cust_stopwords+=['Localisation :','Actions réalisées:']
    cust_stopwords+=['imPulse','Ticket','Description','Note']
    
    regexList=regexList+cust_stopwords
    return regexList

# %%
####################
# Load dataset from file
filepath=r"C:\Mission_SG\Fork\Text-Classification-Project-master\PGS-IN_test.csv"
dfIncidents=pd.read_csv(filepath,sep=";",encoding="iso-8859-1")
#####################

# %%
# Keep only meaningful fields: Title, Incident Description, Solution Journal Events and Id_Incident(Not meaningful)
# Reorder columns
columnsFilter = ['ID','Title','SUMMARY','Solution']

dfIncidents = dfIncidents[columnsFilter]

# %%
print('dfIncidents shape:',dfIncidents.shape)
dfIncidents.head(n=5)
# Out:
# dfIncidents shape: (20009, 4)
#              ID                                              Title  \
# 0  P7IN-0600504  RE: urgent P4 escalated - acces application co...
# 1  P7IN-0875012  { A22/345 / Reparamétrage / Laptop / 1 /  } / ...
# 2  P7IN-1005399  [SUMO] Add PolicyHub intranet in all @Access S...
# 3  P7IN-1005399  [SUMO] Add PolicyHub intranet in all @Access S...
# 4  P7IN-1122690  Malgré changement de poste, GAIA nok\\ { A16FL...
#
#                                              SUMMARY  \
# 0  *********** *** Note: Please check the attachm...
# 1  ----------------------------------------------...
# 2  ***********imPulse Ticket Description ========...
# 3  ***********imPulse Ticket Description ========...
# 4   *** Note: Please check the attachments tab fo...
#
#                                             Solution
# 0                                       Out of scope
# 1  { A22/345 / Reparamétrage / Laptop / 1 /  }\tR...
# 2                                                NaN
# 3                                                NaN
# 4  Création d'un nouveau profil sur la machine et...

# %%
dfTickets=dfIncidents

# %%
# Remove duplicates
columnsToDropDuplicates = ['SUMMARY']
dfTickets = dfTickets.drop_duplicates(columnsToDropDuplicates)
print(dfTickets.shape)
# Out:
# (15844, 4)

# %% [markdown]
# # Saving Simplified csv

# %%
dfTickets.to_csv("PGS-IN_simplified.csv",sep=';',index=False)

# %% [markdown]
# ## Remove text with regex

# %%
# Select columns for cleaning
columnsToClean = ['SUMMARY', 'Title']



# Create list of regex to remove sensitive data
# Clean dataset and remove sensitive data
cleanDataset(dfTickets, columnsToClean, getRegexList())
# Out:
#                  ID IN - Incident Type IN - Critical User  \
# 0      P7IN-0600504           incident             Silver
# 1      P7IN-0875012           incident             Silver
# 2      P7IN-1005399            request             Silver
# 3      P7IN-1005399            request             Silver
# 4      P7IN-1122690           incident             Silver
# 5      P7IN-1130192           incident             Silver
# 6      P7IN-1139110            request               Gold
# 7      P7IN-1152638           incident             Silver
# 8      P7IN-1153634            request             Silver
# 9      P7IN-1163776           incident             Silver
# 10     P7IN-1172881           incident             Silver
# 11     P7IN-1184552            request                NaN
# 12     P7IN-1184552            request                NaN
# 13     P7IN-1197371            request             Silver
# 14     P7IN-1197992            request             Silver
# 15     P7IN-1197992            request             Silver
# 16     P7IN-1199877           incident             Silver
# 17     P7IN-1201786            request             Silver
# 18     P7IN-1201786            request             Silver
# 19     P7IN-1201786            request             Silver
# 20     P7IN-1201786            request             Silver
# 21     P7IN-1206541           incident             Silver
# 22     P7IN-1206785            request             Silver
# 23     P7IN-1224896           incident             Silver
# 24     P7IN-1227772            request             Silver
# 25     P7IN-1227772            request             Silver
# 26     P7IN-1239057           incident             Silver
# 27     P7IN-1247786            request             Silver
# 28     P7IN-1251960           incident             Silver
# 29     P7IN-1252451            request             Silver
# ...             ...                ...                ...
# 19979  P8IN-0368686           incident             Silver
# 19980  P8IN-0368707            request             Silver
# 19981  P8IN-0368756            request             Silver
# 19982  P8IN-0368791           incident             Silver
# 19983  P8IN-0368810           incident             Silver
# 19984  P8IN-0368838           incident             Silver
# 19985  P8IN-0368843            request             Silver
# 19986  P8IN-0368914           incident             Silver
# 19987  P8IN-0368967           incident           Platinum
# 19988  P8IN-0368980           incident             Silver
# 19989  P8IN-0369001            request             Silver
# 19990  P8IN-0369026           incident             Silver
# 19991  P8IN-0369048           incident             Silver
# 19992  P8IN-0369070           incident             Silver
# 19993  P8IN-0369095           incident             Silver
# 19994  P8IN-0369170           incident             Silver
# 19995  P8IN-0369179           incident             Silver
# 19996  P8IN-0369284            request             Silver
# 19997  P8IN-0369361            request             Silver
# 19998  P8IN-0369366           incident             Silver
# 19999  P8IN-0369368            request             Silver
# 20000  P8IN-0369422            request             Silver
# 20001  P8IN-0369475           incident             Silver
# 20002  P8IN-0369480           incident             Silver
# 20003  P8IN-0369498           incident             Silver
# 20004  P8IN-0369525           incident             Silver
# 20005  P8IN-0369599           incident             Silver
# 20006  P8IN-0369601           incident             Silver
# 20007  P8IN-0369602           incident             Silver
# 20008  P8IN-0369617            request             Silver
#
#       IN - 001 - Contact Entity IN - Status                IN - Service  \
# 0              CORI/COV/FRA/COS      Closed            EUS_APPLICATIONS
# 1                  DFIN/DTO/TRF      Closed               EUS_COMPUTERS
# 2          RESG/GTS/DIR/EXP/USA    Assigned               EUS_COMPUTERS
# 3          RESG/GTS/DIR/EXP/USA    Assigned               EUS_COMPUTERS
# 4                  OPER/CMA/RVS      Closed            EUS_APPLICATIONS
# 5                      ASSU/SGK      Closed                IT_TELEPHONY
# 6                  GLFI/COO/ISP      Closed            EUS_APPLICATIONS
# 7                  MCIB/MNA/STG      Closed            EUS_APPLICATIONS
# 8              CORI/CCG/CRE/FIG      Closed            EUS_APPLICATIONS
# 9                      OPER/QTY      Closed               EUS_COMPUTERS
# 10                 RISQ/MAR/RIM      Closed            EUS_APPLICATIONS
# 11         GTPS/GTB/USA/PCM/CMT      Closed               EUS_COMPUTERS
# 12         GTPS/GTB/USA/PCM/CMT      Closed               EUS_COMPUTERS
# 13             ITEC/SGS/SBO/PAR    Assigned                  IT_AD_DATA
# 14                 CLIC/KYC/ECM      Closed            EUS_APPLICATIONS
# 15                 CLIC/KYC/ECM      Closed            EUS_APPLICATIONS
# 16                 CLIC/KYC/NBO      Closed            EUS_APPLICATIONS
# 17                 ITEC/LYX/LYX    Restored  EU_COLLABORATIVE_MESSAGING
# 18                 ITEC/LYX/LYX    Restored  EU_COLLABORATIVE_MESSAGING
# 19                 ITEC/LYX/LYX    Restored  EU_COLLABORATIVE_MESSAGING
# 20                 ITEC/LYX/LYX    Restored  EU_COLLABORATIVE_MESSAGING
# 21                 BANG/ITE/SGS      Closed                  IT_AD_DATA
# 22             CORI/CCG/CRE/COR      Closed                 EUS_AD_DATA
# 23                 ITEC/MKT/DIR      Closed            EUS_APPLICATIONS
# 24             RESG/GTS/MKT/APS      Closed            EUS_APPLICATIONS
# 25             RESG/GTS/MKT/APS      Closed            EUS_APPLICATIONS
# 26             ITEC/SGS/SBO/NAN      Closed               EUS_COMPUTERS
# 27                 ITEC/LYX/LYX    Restored               EUS_COMPUTERS
# 28             DFIN/GBI/CMA/MMC      Closed            EUS_APPLICATIONS
# 29                 ITEC/MKT/DRA      Closed            EUS_APPLICATIONS
# ...                         ...         ...                         ...
# 19979                  DFIN/FNA      Closed               EUS_COMPUTERS
# 19980              CLIC/CXP/CMP      Closed            EUS_APPLICATIONS
# 19981              ITEC/ARC/LAB      Closed            EUS_APPLICATIONS
# 19982      RESG/GTS/GCR/GBI/DEF      Closed            EUS_APPLICATIONS
# 19983                  COOS/ORG      Closed            EUS_APPLICATIONS
# 19984              ITEC/DCC/CSC      Closed               EUS_COMPUTERS
# 19985              ITEC/DCC/DRM      Closed            EUS_APPLICATIONS
# 19986              BDDF/PAY/STI      Closed            EUS_APPLICATIONS
# 19987      MARK/EQD/ENG/PRI/EUR      Closed                 EUS_SGSHARE
# 19988      RESG/GTS/GCR/GBI/DEF      Closed                 EUS_NETWORK
# 19989              ITEC/FRM/CFI      Closed            EUS_APPLICATIONS
# 19990      SGSS/CMS/COV/SRM/PAR      Closed               EUS_TELEPHONY
# 19991          SGSS/SBO/TDS/PAR      Closed            EUS_APPLICATIONS
# 19992      SGSS/SBO/CSS/COR/NAN      Closed       EU_OFFICE_WORKSTATION
# 19993                  MACC/CBA      Closed            EUS_APPLICATIONS
# 19994      SGSS/SBO/CSS/CAS/PAR      Closed               EUS_COMPUTERS
# 19995      SGSS/SBO/CIS/ISS/GMS      Closed       EU_OFFICE_WORKSTATION
# 19996              CPLE/FCC/KYC      Closed  EU_COLLABORATIVE_MESSAGING
# 19997      RESG/GTS/DWS/AST/VDF      Closed            EUS_APPLICATIONS
# 19998          CORI/COV/FRA/INC      Closed                 IT_SECURITY
# 19999      SGSS/SBO/CIS/CAC/PAR      Closed                 EUS_NETWORK
# 20000      SGSS/SBO/CIS/CAC/PAR      Closed                 EUS_NETWORK
# 20001          IGAD/AUD/ICS/DCF      Closed               EUS_COMPUTERS
# 20002      RESG/GTS/GCR/GBI/DEF      Closed                 EUS_AD_DATA
# 20003              ITEC/MKT/VOL      Closed               EUS_COMPUTERS
# 20004              ITEC/MKT/CTY      Closed            EUS_APPLICATIONS
# 20005                  COOS/PPP      Closed               EUS_COMPUTERS
# 20006              ITEC/DCC/PRD      Closed               EUS_COMPUTERS
# 20007      RESG/GTS/TSI/DIR/VDF      Closed               EUS_COMPUTERS
# 20008                  COOS/PPP      Closed               EUS_COMPUTERS
#
#                    IN - Category         IN - Sub-Category  \
# 0               eus_applications     business_applications
# 1                  eus_computers        peripheral_devices
# 2                  eus_computers          virtual_desktops
# 3                  eus_computers          virtual_desktops
# 4               eus_applications     business_applications
# 5                   it_telephony              ip_telephony
# 6               eus_applications     business_applications
# 7                 itsm_interface              itsm_impulse
# 8               eus_applications     business_applications
# 9                  eus_computers                  desktops
# 10              eus_applications     standard_applications
# 11                itsm_interface              itsm_impulse
# 12                itsm_interface              itsm_impulse
# 13                itsm_interface              itsm_impulse
# 14              eus_applications     business_applications
# 15              eus_applications     business_applications
# 16                itsm_interface              itsm_impulse
# 17                itsm_interface              itsm_impulse
# 18                itsm_interface              itsm_impulse
# 19                itsm_interface              itsm_impulse
# 20                itsm_interface              itsm_impulse
# 21                    eu_ad_data          active_directory
# 22                itsm_interface              itsm_impulse
# 23              eus_applications     standard_applications
# 24                itsm_interface              itsm_impulse
# 25                itsm_interface              itsm_impulse
# 26                 eus_computers                  desktops
# 27                 eus_computers                  desktops
# 28              eus_applications  virtualized_applications
# 29              eus_applications     business_applications
# ...                          ...                       ...
# 19979              eus_computers                   laptops
# 19980           eus_applications     standard_applications
# 19981           eus_applications     standard_applications
# 19982           eus_applications     business_applications
# 19983           eus_applications     standard_applications
# 19984              eus_computers                  desktops
# 19985           eus_applications     standard_applications
# 19986           eus_applications     standard_applications
# 19987           eus_applications     standard_applications
# 19988                eus_network             shared_drives
# 19989           eus_applications     business_applications
# 19990              eus_telephony          mobile_telephony
# 19991           eus_applications     business_applications
# 19992             eu_workstation         wks_ndg_nantes_di
# 19993           eus_applications     standard_applications
# 19994  eus_accounts_and_accesses             user_profiles
# 19995             eu_workstation         wks_ndg_nantes_di
# 19996           eu_messaging_com                 messaging
# 19997           eus_applications     standard_applications
# 19998             itsm_interface              itsm_impulse
# 19999                eus_network             shared_drives
# 20000                eus_network             shared_drives
# 20001              eus_computers                   laptops
# 20002  eus_accounts_and_accesses                   windows
# 20003              eus_computers                   laptops
# 20004           eus_applications     standard_applications
# 20005           eus_applications     standard_applications
# 20006           eus_applications     standard_applications
# 20007           eus_applications     standard_applications
# 20008           eus_applications     standard_applications
#
#                              IN - Characterisation  \
# 0                                           create
# 1                                              fix
# 2                                              NaN
# 3                                              NaN
# 4                                              fix
# 5                                        inc-minor
# 6                                              NaN
# 7                                              NaN
# 8                                              fix
# 9                                              fix
# 10                                           other
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             fix
# 17          ope.inc_gen.mail.hermes.mailbox.access
# 18          ope.inc_gen.mail.hermes.mailbox.access
# 19          ope.inc_gen.mail.hermes.mailbox.access
# 20          ope.inc_gen.mail.hermes.mailbox.access
# 21                                             NaN
# 22                                             NaN
# 23                                      ms_outlook
# 24                                             fix
# 25                                             fix
# 26                                             NaN
# 27                                             fix
# 28                                             fix
# 29                                             NaN
# ...                                            ...
# 19979                                          fix
# 19980                                        other
# 19981                                        other
# 19982                                          fix
# 19983                                        other
# 19984                                          NaN
# 19985                                        other
# 19986                                        other
# 19987                                          NaN
# 19988                                          fix
# 19989                                          NaN
# 19990                                          fix
# 19991                                          fix
# 19992              di_messagerie_configuration_bal
# 19993                                        other
# 19994                                          fix
# 19995                   di_application_bureautique
# 19996  ope.req_gen.mail.hermes.mailbox.outofoffice
# 19997                                        other
# 19998                                        other
# 19999                                       modify
# 20000                                       modify
# 20001                                          fix
# 20002                                          fix
# 20003                                          fix
# 20004                                        other
# 20005                                        other
# 20006                                        other
# 20007                                        other
# 20008                                        other
#
#                                                    Title  \
# 0         re:   p4 escalated - acces application contact
# 1      { a22/345 / reparamétrage / laptop / 1 / } / [...
# 2      [sumo] add policyhub intranet in all @access s...
# 3      [sumo] add policyhub intranet in all @access s...
# 4      malgré changement de poste, gaia nok\\ { a16fl...
# 5        [sogecap]-incident de fonctionnement click dial
# 6      [mkdadmin] deletion licence of capital in ligence
# 7                             [#][oscar] demande d'accès
# 8                                  [market data] guibert
# 9                                        [freeze clavier
# 10            [#][environnement] installation de bristol
# 11     new infopooling - access authorisations user list
# 12     new infopooling - access authorisations user list
# 13                                     access ftp lipper
# 14     02nd chase-up-08/11/2017-- bam: - gorka jean-m...
# 15     02nd chase-up-08/11/2017-- bam: - gorka jean-m...
# 16                      execution de bdr scow impossible
# 17                 mail exception rules for server negev
# 18                 mail exception rules for server negev
# 19                 mail exception rules for server negev
# 20                 mail exception rules for server negev
# 21        office 2016 - license issue in vdi fr09547792w
# 22                                  dossiers déplacement
# 23     [o2007][outlook] dysfonctionnement sur les cal...
# 24     gts/gcr/ast : [request] : fix my laptop ip add...
# 25     gts/gcr/ast : [request] : fix my laptop ip add...
# 26                                 sg share : assistance
# 27     blr*** dc 20/11/2017 pr0000072201***ok pour in...
# 28     [#][internet] ne peut voire les graphiques sur...
# 29                              [mkdadmin] request title
# ...                                                  ...
# 19979                            def # assistance laptop
# 19980  installation "main courante constatation" //  ...
# 19981                fw: installation drvier oracle odbc
# 19982                                   re: réponse jump
# 19983               [#]problème lancement apps on demand
# 19984                      [cds/del]template_transfertl3
# 19985                       [#]demande d'accès à l'appli
# 19986                   [#][impact] ne peut se connecter
# 19987  unable to access f:\public-purged-every-7-days...
# 19988               acces shared drives resg gts mkt gim
# 19989                           [mkdadmin] request title
# 19990  [#][blackberry work] - clé d'activation non gé...
# 19991                               problème d'archivage
# 19992                             outlook : bal partagee
# 19993                   [#]problème d'accès à un fichier
# 19994  [#][account and acces] badge bloqué malgrès le...
# 19995          demande d'habilitation adobe acrobate pro
# 19996      pour le 09/04 out of office sur boite commune
# 19997   [conex] installation bloomberg sur poste de test
# 19998                                   probleme website
# 19999                    demande d'accès aux disque pour
# 20000                  re: demande d'accès à pour phuong
# 20001                    souhaite avoir microsoft access
# 20002        [#][badge] probleme de conenction opentrust
# 20003  besoin daide pour un programme car il na pas l...
# 20004               windows explorer plante au demarrage
# 20005                      [selfcare] mise jour logiciel
# 20006          [aod-v3] erreur systématique au lancement
# 20007      [aod] n'affiche plus les packages applicatifs
# 20008                    mise à jour du logiciel tableau
#
#                   ...                    IN - Open Time      IN - Close Date  \
# 0                 ...               16/05/2017 13:55:20  25/01/2018 15:06:58
# 1                 ...               19/07/2017 14:40:53  29/03/2018 19:41:16
# 2                 ...               24/08/2017 01:33:53  01/01/1900 00:00:00
# 3                 ...               24/08/2017 01:33:53  01/01/1900 00:00:00
# 4                 ...               22/09/2017 16:16:21  09/05/2018 17:20:05
# 5                 ...               25/09/2017 11:49:09  20/04/2018 16:02:39
# 6                 ...               26/09/2017 17:56:38  18/01/2018 08:35:47
# 7                 ...               29/09/2017 14:50:46  22/12/2017 13:57:46
# 8                 ...               29/09/2017 17:54:04  12/12/2017 08:33:13
# 9                 ...               03/10/2017 10:15:17  05/12/2017 09:58:30
# 10                ...               04/10/2017 15:29:18  20/12/2017 14:34:00
# 11                ...               06/10/2017 17:29:53  21/12/2017 09:37:49
# 12                ...               06/10/2017 17:29:53  21/12/2017 09:37:49
# 13                ...               10/10/2017 16:45:23  01/01/1900 00:00:00
# 14                ...               10/10/2017 19:54:26  01/03/2018 10:46:43
# 15                ...               10/10/2017 19:54:26  01/03/2018 10:46:43
# 16                ...               11/10/2017 09:56:53  02/01/2018 15:27:22
# 17                ...               11/10/2017 15:09:10  01/01/1900 00:00:00
# 18                ...               11/10/2017 15:09:10  01/01/1900 00:00:00
# 19                ...               11/10/2017 15:09:10  01/01/1900 00:00:00
# 20                ...               11/10/2017 15:09:10  01/01/1900 00:00:00
# 21                ...               12/10/2017 13:49:03  21/12/2017 09:35:00
# 22                ...               12/10/2017 14:32:06  30/01/2018 17:42:11
# 23                ...               17/10/2017 14:37:33  28/12/2017 17:01:59
# 24                ...               18/10/2017 08:22:10  20/12/2017 12:01:54
# 25                ...               18/10/2017 08:22:10  20/12/2017 12:01:54
# 26                ...               20/10/2017 11:31:28  11/01/2018 16:01:33
# 27                ...               23/10/2017 15:22:42  01/01/1900 00:00:00
# 28                ...               24/10/2017 13:09:28  22/12/2017 14:17:36
# 29                ...               24/10/2017 14:31:24  08/12/2017 14:19:50
# ...               ...                               ...                  ...
# 19979             ...               30/03/2018 15:39:38  05/04/2018 15:26:38
# 19980             ...               30/03/2018 15:43:51  03/04/2018 14:43:05
# 19981             ...               30/03/2018 15:52:37  03/04/2018 10:00:16
# 19982             ...               30/03/2018 16:00:26  12/04/2018 12:13:14
# 19983             ...               30/03/2018 16:02:48  30/03/2018 16:40:15
# 19984             ...               30/03/2018 16:09:38  26/04/2018 21:35:38
# 19985             ...               30/03/2018 16:10:39  09/04/2018 11:11:19
# 19986             ...               30/03/2018 16:22:08  05/04/2018 16:37:51
# 19987             ...               30/03/2018 16:31:58  04/04/2018 15:30:48
# 19988             ...               30/03/2018 16:33:53  05/04/2018 09:20:02
# 19989             ...               30/03/2018 16:37:09  13/04/2018 13:46:56
# 19990             ...               30/03/2018 16:39:50  05/05/2018 11:05:13
# 19991             ...               30/03/2018 16:45:06  05/04/2018 10:30:53
# 19992             ...               30/03/2018 16:47:29  04/05/2018 15:49:01
# 19993             ...               30/03/2018 16:51:29  05/04/2018 14:35:33
# 19994             ...               30/03/2018 17:07:25  06/04/2018 17:15:24
# 19995             ...               30/03/2018 17:09:41  04/04/2018 11:48:04
# 19996             ...               30/03/2018 17:38:10  16/04/2018 12:16:21
# 19997             ...               30/03/2018 18:01:46  03/04/2018 08:57:30
# 19998             ...               30/03/2018 18:02:51  24/04/2018 14:16:22
# 19999             ...               30/03/2018 18:03:41  13/04/2018 14:16:24
# 20000             ...               30/03/2018 18:10:32  03/04/2018 11:42:58
# 20001             ...               30/03/2018 18:29:32  11/04/2018 10:12:47
# 20002             ...               30/03/2018 18:32:42  10/04/2018 15:39:18
# 20003             ...               30/03/2018 18:43:19  04/04/2018 12:12:18
# 20004             ...               30/03/2018 18:50:47  05/04/2018 14:06:11
# 20005             ...               30/03/2018 19:24:42  04/04/2018 11:12:28
# 20006             ...               30/03/2018 19:25:37  10/04/2018 14:11:27
# 20007             ...               30/03/2018 19:26:13  05/04/2018 14:58:15
# 20008             ...               30/03/2018 19:32:28  11/04/2018 10:10:59
#
#                IN - Assignment Group       IN - EUS - Follow Group  \
# 0        GTS_PAR_EUS_35000.SILVER_L2  GTS_PAR_EUS_35000.REQUEST_L1
# 1        GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 2            GTS_PAR_EUS_IPM.ISM.OPE                           NaN
# 3            GTS_PAR_EUS_IPM.ISM.OPE                           NaN
# 4        GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 5       GTS_FR_EUS_PRX.OSS.ORLEAN_L3                           NaN
# 6          GTS_PAR_EUS_35000.GOLD_L2     GTS_PAR_EUS_35000.GOLD_L2
# 7          GTS_PAR_EUS_35000.GOLD_L2     GTS_PAR_EUS_35000.GOLD_L2
# 8        GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 9        GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 10       GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 11       GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 12       GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 13      ITEC_FR_SGS_SBO.ETI_Trust_RM                           NaN
# 14       GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 15       GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 16       GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 17               gts_wwi_ssb_app_unx                           NaN
# 18               gts_wwi_ssb_app_unx                           NaN
# 19               gts_wwi_ssb_app_unx                           NaN
# 20               gts_wwi_ssb_app_unx                           NaN
# 21               GTS_PAR_EUS_CORP_L2                           NaN
# 22       GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 23       GTS_PAR_EUS_WIN10-Off365_L2   GTS_PAR_EUS_35000.SILVER_L2
# 24       GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 25       GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 26     GTS_PAR_EUS_WKS.NDG.NANTES.L2   GTS_PAR_EUS_35000.SILVER_L2
# 27       GTS_PAR_EUS_35000.SILVER_L2          GTS_PAR_EUS_35000_L1
# 28       GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 29       GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# ...                              ...                           ...
# 19979    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19980    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19981    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19982    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19983    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19984    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19985    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19986    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19987       GTS_PAR_EUS_AD.DM.OPE_L1  GTS_PAR_EUS_35000.PLATINM_L2
# 19988    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19989    GTS_PAR_EUS_35000.SILVER_L2   GTS_PAR_EUS_35000.SILVER_L2
# 19990   GTS_PAR_EUS_MOBILE.DEVICE_L2                           NaN
# 19991    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19992    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19993    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19994    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19995    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19996     GTS_PAR_EUS_MSG.SHP.OPE_L1   GTS_PAR_EUS_35000.SILVER_L2
# 19997      GTS_PAR_EUS_35000.GOLD_L2                           NaN
# 19998    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 19999       GTS_PAR_EUS_AD.DM.OPE_L2   GTS_PAR_EUS_35000.SILVER_L2
# 20000    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20001           GTS_PAR_EUS_35000_L1                           NaN
# 20002    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20003    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20004    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20005    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20006    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20007    GTS_PAR_EUS_35000.SILVER_L2                           NaN
# 20008    GTS_PAR_EUS_35000.SILVER_L2                           NaN
#
#                   IN - Open By Group         IN - Restored By Group  \
# 0               GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 1               GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 2               GTS_PAR_EUS_35000_L1                            NaN
# 3               GTS_PAR_EUS_35000_L1                            NaN
# 4               GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 5              GTS_FR_EUS_PRX.SVP_L1   GTS_FR_EUS_PRX.OSS.ORLEAN_L3
# 6               GTS_PAR_EUS_35000_L1      GTS_PAR_EUS_35000.GOLD_L2
# 7               GTS_PAR_EUS_35000_L1      GTS_PAR_EUS_35000.GOLD_L2
# 8               GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 9               GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 10              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 11                  gts_ame_helpdesk    GTS_PAR_EUS_35000.SILVER_L2
# 12                  gts_ame_helpdesk    GTS_PAR_EUS_35000.SILVER_L2
# 13            ITEC_FR_SGS_GAP.CUS_L1                            NaN
# 14              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 15              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 16     GTS_PAR_EUS_35000.STRG.AUT_L1    GTS_PAR_EUS_35000.SILVER_L2
# 17              GTS_PAR_EUS_35000_L1            gts_wwi_ssb_app_unx
# 18              GTS_PAR_EUS_35000_L1            gts_wwi_ssb_app_unx
# 19              GTS_PAR_EUS_35000_L1            gts_wwi_ssb_app_unx
# 20              GTS_PAR_EUS_35000_L1            gts_wwi_ssb_app_unx
# 21                    GTS_IN_EUS_USU            GTS_PAR_EUS_CORP_L2
# 22       GTS_PAR_EUS_35000.SILVER_L2    GTS_PAR_EUS_35000.SILVER_L2
# 23              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_WIN10-Off365_L2
# 24              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 25              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 26     GTS_PAR_EUS_WKS.NDG.NANTES_L1  GTS_PAR_EUS_WKS.NDG.NANTES.L2
# 27              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 28              GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 29         GTS_PAR_EUS_ASSET.DATA_L2    GTS_PAR_EUS_35000.SILVER_L2
# ...                              ...                            ...
# 19979     GTS_PAR_EUS_OSS.GUICHET_L2    GTS_PAR_EUS_35000.SILVER_L2
# 19980           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19981   GTS_PAR_EUS_35000.REQUEST_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19982           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19983           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19984                            NaN    GTS_PAR_EUS_35000.SILVER_L2
# 19985           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19986           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19987           GTS_PAR_EUS_35000_L1       GTS_PAR_EUS_AD.DM.OPE_L1
# 19988           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19989   GTS_PAR_EUS_35000.REQUEST_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19990           GTS_PAR_EUS_35000_L1   GTS_PAR_EUS_MOBILE.DEVICE_L2
# 19991           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19992  GTS_PAR_EUS_WKS.NDG.NANTES_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19993           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19994           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19995  GTS_PAR_EUS_WKS.NDG.NANTES_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19996      GTS_PAR_EUS_35000.TOIP_L1     GTS_PAR_EUS_MSG.SHP.OPE_L1
# 19997   GTS_PAR_EUS_35000.REQUEST_L1      GTS_PAR_EUS_35000.GOLD_L2
# 19998      GTS_PAR_EUS_35000.TOIP_L1    GTS_PAR_EUS_35000.SILVER_L2
# 19999   GTS_PAR_EUS_35000.REQUEST_L1       GTS_PAR_EUS_AD.DM.OPE_L2
# 20000   GTS_PAR_EUS_35000.REQUEST_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20001      GTS_PAR_EUS_35000.TOIP_L1           GTS_PAR_EUS_35000_L1
# 20002           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20003      GTS_PAR_EUS_35000.TOIP_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20004           GTS_PAR_EUS_35000_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20005   GTS_PAR_EUS_35000.ESCALTN_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20006   GTS_PAR_EUS_35000.ESCALTN_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20007   GTS_PAR_EUS_35000.ESCALTN_L1    GTS_PAR_EUS_35000.SILVER_L2
# 20008   GTS_PAR_EUS_35000.ESCALTN_L1    GTS_PAR_EUS_35000.SILVER_L2
#
#       IN - Previous Assignment Group    IN - Activity Description  \
# 0               GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 1                GTS_PAR_EUS_OSS.DEF  GTS_PAR_EUS_35000.SILVER_L2
# 2               GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 3               GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 4               GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 5          GTS_PAR_EUS_35000.TOIP_L1  GTS_PAR_EUS_35000.SILVER_L2
# 6                gts_par_mkt_mkd_mda    GTS_PAR_EUS_35000.GOLD_L2
# 7       ITEC_SGS_SBO.TIPS_SUPPORT_L1    GTS_PAR_EUS_35000.GOLD_L2
# 8                gts_par_mkt_mkd_mda  GTS_PAR_EUS_35000.SILVER_L2
# 9               GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 10         GTS_PAR_EUS_ASSET.DATA_L2  GTS_PAR_EUS_35000.SILVER_L2
# 11      GTS_PAR_EUS_35000.ESCALTN_L1  GTS_PAR_EUS_35000.SILVER_L2
# 12      GTS_PAR_EUS_35000.REQUEST_L1  GTS_PAR_EUS_35000.SILVER_L2
# 13              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 14              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 15               gts_par_mkt_mkd_mda  GTS_PAR_EUS_35000.SILVER_L2
# 16           fcc_wwi_osd_sup_kyc_kyr  GTS_PAR_EUS_35000.SILVER_L2
# 17              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 18              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 19              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 20        GTS_PAR_EUS_MSG.SHP.OPE_L1  GTS_PAR_EUS_35000.SILVER_L2
# 21              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 22          GTS_PAR_EUS_AD.DM.OPE_L1  GTS_PAR_EUS_35000.SILVER_L2
# 23            GTS_PAR_EUS_WKS.OPE_L3  GTS_PAR_EUS_35000.SILVER_L2
# 24              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 25      GTS_PAR_EUS_35000.REQUEST_L1  GTS_PAR_EUS_35000.SILVER_L2
# 26     GTS_PAR_EUS_WKS.NDG.NANTES.L2  GTS_PAR_EUS_35000.SILVER_L2
# 27              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 28              GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 29               gts_par_mkt_mkd_mda  GTS_PAR_EUS_35000.SILVER_L2
# ...                              ...                          ...
# 19979                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19980                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19981   GTS_PAR_EUS_35000.REQUEST_L1  GTS_PAR_EUS_35000.SILVER_L2
# 19982                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19983                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19984           GTS_PAR_EUS_35000_L1  GTS_PAR_EUS_35000.SILVER_L2
# 19985                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19986                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19987                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19988                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19989   GTS_PAR_EUS_35000.REQUEST_L1  GTS_PAR_EUS_35000.SILVER_L2
# 19990                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19991                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19992  GTS_PAR_EUS_WKS.NDG.NANTES_L1  GTS_PAR_EUS_35000.SILVER_L2
# 19993                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19994                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19995  GTS_PAR_EUS_WKS.NDG.NANTES_L1  GTS_PAR_EUS_35000.SILVER_L2
# 19996                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19997                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19998                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 19999   GTS_PAR_EUS_35000.REQUEST_L1  GTS_PAR_EUS_35000.SILVER_L2
# 20000                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20001                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20002                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20003                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20004                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20005                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20006                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20007                            NaN  GTS_PAR_EUS_35000.SILVER_L2
# 20008                            NaN  GTS_PAR_EUS_35000.SILVER_L2
#
#         IN - Activity Date             IN - Clock Group
# 0      24/01/2018 16:42:27  GTS_PAR_EUS_35000.SILVER_L2
# 1      29/03/2018 19:40:53  GTS_PAR_EUS_35000.SILVER_L2
# 2      23/03/2018 09:23:23  GTS_PAR_EUS_35000.SILVER_L2
# 3      23/03/2018 16:32:01  GTS_PAR_EUS_35000.SILVER_L2
# 4      22/01/2018 17:58:20  GTS_PAR_EUS_35000.SILVER_L2
# 5      17/01/2018 17:52:31  GTS_PAR_EUS_35000.SILVER_L2
# 6      18/01/2018 08:34:57  GTS_PAR_EUS_35000.SILVER_L2
# 7      22/12/2017 13:57:20  GTS_PAR_EUS_35000.SILVER_L2
# 8      12/12/2017 08:30:47  GTS_PAR_EUS_35000.SILVER_L2
# 9      04/12/2017 16:07:22  GTS_PAR_EUS_35000.SILVER_L2
# 10     19/12/2017 15:12:04  GTS_PAR_EUS_35000.SILVER_L2
# 11     19/12/2017 16:27:26  GTS_PAR_EUS_35000.SILVER_L2
# 12     20/12/2017 09:11:28  GTS_PAR_EUS_35000.SILVER_L2
# 13     20/03/2018 19:44:07  GTS_PAR_EUS_35000.SILVER_L2
# 14     09/02/2018 14:46:54  GTS_PAR_EUS_35000.SILVER_L2
# 15     10/01/2018 15:22:55  GTS_PAR_EUS_35000.SILVER_L2
# 16     02/01/2018 15:26:15  GTS_PAR_EUS_35000.SILVER_L2
# 17     12/12/2017 08:50:20  GTS_PAR_EUS_35000.SILVER_L2
# 18     26/12/2017 17:41:53  GTS_PAR_EUS_35000.SILVER_L2
# 19     28/12/2017 14:21:36  GTS_PAR_EUS_35000.SILVER_L2
# 20     26/12/2017 06:41:09  GTS_PAR_EUS_35000.SILVER_L2
# 21     11/12/2017 15:21:34  GTS_PAR_EUS_35000.SILVER_L2
# 22     30/01/2018 13:54:16  GTS_PAR_EUS_35000.SILVER_L2
# 23     06/12/2017 12:51:58  GTS_PAR_EUS_35000.SILVER_L2
# 24     13/12/2017 08:28:15  GTS_PAR_EUS_35000.SILVER_L2
# 25     05/12/2017 15:35:00  GTS_PAR_EUS_35000.SILVER_L2
# 26     02/01/2018 14:19:54  GTS_PAR_EUS_35000.SILVER_L2
# 27     06/12/2017 08:06:37  GTS_PAR_EUS_35000.SILVER_L2
# 28     21/12/2017 11:28:28  GTS_PAR_EUS_35000.SILVER_L2
# 29     08/12/2017 14:19:23  GTS_PAR_EUS_35000.SILVER_L2
# ...                    ...                          ...
# 19979  30/03/2018 15:39:39  GTS_PAR_EUS_35000.SILVER_L2
# 19980  30/03/2018 15:43:52  GTS_PAR_EUS_35000.SILVER_L2
# 19981  30/03/2018 16:16:53  GTS_PAR_EUS_35000.SILVER_L2
# 19982  30/03/2018 16:00:28  GTS_PAR_EUS_35000.SILVER_L2
# 19983  30/03/2018 16:02:49  GTS_PAR_EUS_35000.SILVER_L2
# 19984  30/03/2018 18:17:58  GTS_PAR_EUS_35000.SILVER_L2
# 19985  30/03/2018 16:10:40  GTS_PAR_EUS_35000.SILVER_L2
# 19986  30/03/2018 16:22:09  GTS_PAR_EUS_35000.SILVER_L2
# 19987  30/03/2018 16:31:59  GTS_PAR_EUS_35000.SILVER_L2
# 19988  30/03/2018 16:33:53  GTS_PAR_EUS_35000.SILVER_L2
# 19989  30/03/2018 16:45:51  GTS_PAR_EUS_35000.SILVER_L2
# 19990  30/03/2018 16:39:51  GTS_PAR_EUS_35000.SILVER_L2
# 19991  30/03/2018 16:45:07  GTS_PAR_EUS_35000.SILVER_L2
# 19992  30/03/2018 16:47:43  GTS_PAR_EUS_35000.SILVER_L2
# 19993  30/03/2018 16:51:31  GTS_PAR_EUS_35000.SILVER_L2
# 19994  30/03/2018 17:07:26  GTS_PAR_EUS_35000.SILVER_L2
# 19995  30/03/2018 17:09:52  GTS_PAR_EUS_35000.SILVER_L2
# 19996  30/03/2018 17:38:10  GTS_PAR_EUS_35000.SILVER_L2
# 19997  30/03/2018 18:01:46  GTS_PAR_EUS_35000.SILVER_L2
# 19998  30/03/2018 18:02:53  GTS_PAR_EUS_35000.SILVER_L2
# 19999  30/03/2018 18:07:00  GTS_PAR_EUS_35000.SILVER_L2
# 20000  30/03/2018 18:10:33  GTS_PAR_EUS_35000.SILVER_L2
# 20001  30/03/2018 18:29:33  GTS_PAR_EUS_35000.SILVER_L2
# 20002  30/03/2018 18:32:43  GTS_PAR_EUS_35000.SILVER_L2
# 20003  30/03/2018 18:43:20  GTS_PAR_EUS_35000.SILVER_L2
# 20004  30/03/2018 18:50:48  GTS_PAR_EUS_35000.SILVER_L2
# 20005  30/03/2018 19:24:43  GTS_PAR_EUS_35000.SILVER_L2
# 20006  30/03/2018 19:25:37  GTS_PAR_EUS_35000.SILVER_L2
# 20007  30/03/2018 19:26:14  GTS_PAR_EUS_35000.SILVER_L2
# 20008  30/03/2018 19:32:28  GTS_PAR_EUS_35000.SILVER_L2
#
# [20009 rows x 22 columns]

# %% [markdown]
# ## Save dataset and removed words to csv

# %%
dfTickets_clean=dfTickets

# %%
# Save cleaned dataset back to csv without indexes
dfTickets.to_csv('tickets_preprocessed.csv', index=False, index_label=False, sep=";",encoding="iso-8859-1")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-13-25608390fef7> in <module>()
#       1 # Save cleaned dataset back to csv without indexes
# ----> 2 dfTickets.to_csv('tickets_preprocessed.csv', index=False, index_label=False, sep=";",encoding="iso-8859-1")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'tickets_preprocessed.csv'

# %%
import re

# %%
i=55

# %%
i=i+1
text=dfIncidents['SUMMARY'][i]
text
# Out:
# '*********** *** Note: Please check the attachments tab for complete email including print screens or attachments ***     From: JABIN Germain ItecDccCsc  Sent: Thursday, November 09, 2017 3:17 PM To: Call-Center 35000 Subject: Installation Visual Studio       Bonjour,     Pourriez-vous installer Microsoft Visual Studio 2013 sur la VDI « FR09544735W» ?  ·         CA = 29589  ·         Code TBS = S39636 Cdt     **********************'

# %%
regex = r"Subject?:.*(:?\w)"
matches = re.finditer(regex, text, re.MULTILINE)
text_parse=re.findall(regex, text, re.MULTILINE)[0][0]
print(text_parse)
regex_stop=r'Tel.?:'
re.sub(regex_stop,'',text_parse)
# Out:
# t
# 't'

# %%
regex = r"b?jec?t?:.*(:?\w)"
m=re.search(regex, text)
text_parse=m.group(0)
print(text_parse)
regex_stop=r'Tel.?:'
re.sub(regex_stop,'',text_parse)
# Out:
# bject: Installation Visual Studio       Bonjour,     Pourriez-vous installer Microsoft Visual Studio 2013 sur la VDI « FR09544735W» ?  ·         CA = 29589  ·         Code TBS = S39636 Cdt
# 'bject: Installation Visual Studio       Bonjour,     Pourriez-vous installer Microsoft Visual Studio 2013 sur la VDI « FR09544735W» ?  ·         CA = 29589  ·         Code TBS = S39636 Cdt'

# %%
re.finditer(regex, text)

# %%
m=re.search(regex, 'salut')
bool(m)
m.group(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-7f75c0c8e206> in <module>()
#       1 m=re.search(regex, 'salut')
#       2 bool(m)
# ----> 3 m.group(0)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
text_parse.lower().replace(r'c?dt', ' ')
# Out:
# 'subject: installation visual studio       bonjour,     pourriez-vous installer microsoft visual studio 2013 sur la vdi « fr09544735w» ?  ·         ca = 29589  ·         code tbs = s39636 cdt'

# %%
m = re.search('(?<=abc)def', 'abcdef')
m.group(0)

# %%
[matches].start(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-ca5abe79affc> in <module>()
# ----> 1 [matches].start(1)
#
# AttributeError: 'list' object has no attribute 'start'

# %%
# coding=utf8
# the above tag defines encoding for this document and is for Python 2.x compatibility

import re

regex = r"Subject?:.*(:?\w)"

test_str = "*********** *** Note: Please check the attachments tab for complete email including print screens or attachments ***     From: JABIN Germain ItecDccCsc  Sent: Thursday, November 09, 2017 3:17 PM To: Call-Center 35000 Subject: Installation Visual Studio       Bonjour,     Pourriez-vous installer Microsoft Visual Studio 2013 sur la VDI « FR09544735W» ?  ·         CA = 29589  ·         Code TBS = S39636 Cdt  **********************"

matches = re.finditer(regex, test_str, re.MULTILINE)

for matchNum, match in enumerate(matches):
    matchNum = matchNum + 1
    
    print ("Match {matchNum} was found at {start}-{end}: {match}".format(matchNum = matchNum, start = match.start(), end = match.end(), match = match.group()))
    
    for groupNum in range(0, len(match.groups())):
        groupNum = groupNum + 1
        
        print ("Group {groupNum} found at {start}-{end}: {group}".format(groupNum = groupNum, start = match.start(groupNum), end = match.end(groupNum), group = match.group(groupNum)))

# Note: for Python 2.7 compatibility, use ur"" to prefix the regex and u"" to prefix the test string and substitution.
# Out:
# Match 1 was found at 217-407: Subject: Installation Visual Studio       Bonjour,     Pourriez-vous installer Microsoft Visual Studio 2013 sur la VDI « FR09544735W» ?  ·         CA = 29589  ·         Code TBS = S39636 Cdt
# Group 1 found at 406-407: t

# %%
dfTickets_clean['SUMMARY'][0]
# Out:
# '                   please check the attachments tab for complete email including print screens or attachments        guibert remi coricovfracos  tuesday  may               am  call center        re    p  escalated   acces application contact    high   bonjour   pouvez vous svp proc der aux m j pr alables informatiques ci dessous     si besoin merci de vous rapprocher de marie josee rei pour les pr cisions techniques   merci svp de m informer de l avanc e de ce   p       escalad   la demande est  e  merci  bien cordialement  r mi       remi guibert      coverage and investment banking   americas   asian groups                                 remi guibert sgcib com         hotline manageriale bddfcooqsahlm  tuesday    may             guibert remi coricovfracos  hotline manageriale bddfcooqsahlm  re      feedback    contact application access p        bddf coo   hotline manageriale     assistance manageriale       c    publication interne          bonjour monsieur guibert   ci dessous le retour de la responsable supervision applicative en charge de contact   de nombreuses actions v rifications sont   effectuer par vous m me ou par votre support informatique  je vous laisse en prendre connaissance   cordialement     kevin hotline manag riale direction de l organisation du r seau france pour mieux nous conna tre   bddf coo              de   rei marie josee itimgsisfivdf envoy    lundi    mai                hotline manageriale bddfcooqsahlm objet       feedback    contact application access p   bonjour   si je prend l exemple de s bastien foubert de pallieres  celui ci apparait bien comme acteur grc et est identifi  avec son matricule      de m me sous sgh  il est identifi  par les m mes attributs   donc  remi guibert doit s assurer '

# %%
df=dfIncidents['SUMMARY']

# %%
df.head()
# Out:
# 0    *********** *** Note: Please check the attachm...
# 1    ----------------------------------------------...
# 2    ***********imPulse Ticket Description ========...
# 3    ***********imPulse Ticket Description ========...
# 4     *** Note: Please check the attachments tab fo...
# Name: SUMMARY, dtype: object

# %%
def lowing(x):
    return x.lower()

# %%
df1=df.apply(lowing)

# %%
df1.head()
# Out:
# 0    *********** *** note: please check the attachm...
# 1    ----------------------------------------------...
# 2    ***********impulse ticket description ========...
# 3    ***********impulse ticket description ========...
# 4     *** note: please check the attachments tab fo...
# Name: SUMMARY, dtype: object

# %%
def filtering(text):
    # Note Class
    regex_Note_Class = r"b?jec?t?:.*(:?\w)"
    m=re.search(regex_Note_Class, text)
    if bool(m):
        text_parse_Note_Class=m.group(0)
        regex_stop_Note_Class=r'Tel.?:'
        return re.sub(regex_stop_Note_Class,'',text_parse_Note_Class)

# %%
df1.apply(filtering)[4]
# Out:
# 'bjet: re: p7it-0337755 submitted - fw: incidents pc : appsondemand et acrobat reader bonjour karl, sauf erreur, je suis tjrs en attente d\x92une réponse de votre part. est-ce que vous avez pu avancer sur le sujet? merci d\x92avance pour votre aide sur le sujet.  bien cordialement / best regards, ludivine dubois oper/rvs   from: dubois ludivine operrvs  sent: monday 18 september 2017 11:07 to: querville karl (ext) resggtseususugbi subject: re: p7it-0337755 submitted - fw: incidents pc : appsondemand et acrobat reader bonjour karl, je vous confirme que mon application gaia ne fonctione toujours pas. est-ce que vous pourriez revoir? merci d\x92avance pour votre aide.  bien cordialement / best regards, ludivine dubois oper/rvs   from: querville karl (ext) resggtseususugbi  sent: thursday 11 may 2017 14:23 to: dubois ludivine operrvs subject: re: p7it-0337755 submitted - fw: incidents pc : appsondemand et acrobat reader bonjour mme perrou, j\x92attends un retour de la part des gestionnaires télétravail. je devrais avoir un retour aujourd\x92hui. cordialement/regards,karl quervillesupport 35000 \x96 expert gbis société jems group en prestation à la société générale resg/gts/eus/usu/gbi immeuble alicante 17, cours valmy 92800 puteaux tel: (&#43;33) 1 58 98 09 44 mail: karl.querville-ext@socgen.com pour les procédures pas-à-pas et le suivi de vos tickets, consultez selfcare for step-by-step tutorials and tickets management, please visit selfcare   de: dubois ludivine operrvs  envoyé: jeudi 11 mai 2017 13:22 à: querville karl (ext) resggtseususugbi cc: it-support-notification objet: re: p7it-0337755 submitted - fw: incidents pc : appsondemand et'
